# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from pandas_datareader import get_data_yahoo as yahoo
from pandas_datareader.data import YahooOptions as opt
from datetime import datetime as date
import mplfinance as mpl
from fbprophet import Prophet
from yfinance import download as tick
import requests

# %%
IS = requests.get(f'https://financialmodelingprep.com/api/v3/income-statement/GOF?apikey=4ecd59e2fd2318e9541674d428e1af84').json()

# %%
IS
# Out:
# [{'date': '2021-05-31',
#   'symbol': 'GOF',
#   'reportedCurrency': 'USD',
#   'fillingDate': '2021-05-31',
#   'acceptedDate': '2021-05-31',
#   'period': 'FY',
#   'revenue': 159243781,
#   'costOfRevenue': 0.0,
#   'grossProfit': 0.0,
#   'grossProfitRatio': 0.0,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 1426287.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 1426287.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 1448449.0,
#   'costAndExpenses': 0.0,
#   'interestExpense': 2153731.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 0.0,
#   'ebitdaratio': 0.0,
#   'operatingIncome': 0.0,
#   'operatingIncomeRatio': 0.0,
#   'totalOtherIncomeExpensesNet': 0.0,
#   'incomeBeforeTax': 157795332,
#   'incomeBeforeTaxRatio': 0.9909042036624338,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 157795332,
#   'netIncomeRatio': 0.9909042036624338,
#   'eps': 3.719305558239967,
#   'epsdiluted': 3.719305558239967,
#   'weightedAverageShsOut': 42426020,
#   'weightedAverageShsOutDil': 42426020,
#   'link': '',
#   'finalLink': ''},
#  {'date': '2020-05-31',
#   'symbol': 'GOF',
#   'reportedCurrency': 'USD',
#   'fillingDate': '2020-05-31',
#   'acceptedDate': '2020-05-31',
#   'period': 'FY',
#   'revenue': 42987180,
#   'costOfRevenue': 7776590.0,
#   'grossProfit': 35210590,
#   'grossProfitRatio': 0.8190951348750953,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 1044725.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 1065505.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 1065505.0,
#   'costAndExpenses': 7956020.0,
#   'interestExpense': -63366290,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': -91701420,
#   'ebitdaratio': -2.133227,
#   'operatingIncome': 35031160,
#   'operatingIncomeRatio': 0.8149210997325249,
#   'totalOtherIncomeExpensesNet': 63366290,
#   'incomeBeforeTax': -28335130,
#   'incomeBeforeTaxRatio': -0.659153031206048,
#   'incomeTaxExpense': 0.0,
#   'netIncome': -28335130,
#   'netIncomeRatio': -0.659153031206048,
#   'eps': -0.66787,
#   'epsdiluted': -0.66787,
#   'weightedAverageShsOut': 42426020,
#   'weightedAverageShsOutDil': 42426020,
#   'link': '',
#   'finalLink': ''},
#  {'date': '2019-05-31',
#   'symbol': 'GOF',
#   'reportedCurrency': 'USD',
#   'fillingDate': '2019-05-31',
#   'acceptedDate': '2019-05-31',
#   'period': 'FY',
#   'revenue': 37383380,
#   'costOfRevenue': 6712450.0,
#   'grossProfit': 30670930,
#   'grossProfitRatio': 0.8204429348015081,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 844365.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 861558.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 861558.0,
#   'costAndExpenses': 6824440.000000001,
#   'interestExpense': -12051330,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 6456270.0,
#   'ebitdaratio': 0.172704,
#   'operatingIncome': 30558940,
#   'operatingIncomeRatio': 0.8174472185233117,
#   'totalOtherIncomeExpensesNet': 12051340,
#   'incomeBeforeTax': 18507600,
#   'incomeBeforeTaxRatio': 0.49507561916552223,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 18507600,
#   'netIncomeRatio': 0.49507561916552223,
#   'eps': 0.51631,
#   'epsdiluted': 0.51631,
#   'weightedAverageShsOut': 35845940,
#   'weightedAverageShsOutDil': 35845940,
#   'link': '',
#   'finalLink': ''},
#  {'date': '2018-05-31',
#   'symbol': 'GOF',
#   'reportedCurrency': 'USD',
#   'fillingDate': '2018-05-31',
#   'acceptedDate': '2018-05-31',
#   'period': 'FY',
#   'revenue': 36466670,
#   'costOfRevenue': 6899780.0,
#   'grossProfit': 29566890,
#   'grossProfitRatio': 0.8107921562347207,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 857161.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 1092840.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 1092840.0,
#   'costAndExpenses': 7129150.0,
#   'interestExpense': -1101490.0,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 27134530,
#   'ebitdaratio': 0.744091,
#   'operatingIncome': 29337520,
#   'operatingIncomeRatio': 0.8045023030619467,
#   'totalOtherIncomeExpensesNet': 1101500.0,
#   'incomeBeforeTax': 28236020,
#   'incomeBeforeTaxRatio': 0.7742966385469252,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 28236020,
#   'netIncomeRatio': 0.7742966385469252,
#   'eps': 1.01812,
#   'epsdiluted': 1.01812,
#   'weightedAverageShsOut': 27733510,
#   'weightedAverageShsOutDil': 27733510,
#   'link': '',
#   'finalLink': ''},
#  {'date': '2017-05-31',
#   'symbol': 'GOF',
#   'reportedCurrency': 'USD',
#   'fillingDate': '2017-05-31',
#   'acceptedDate': '2017-05-31',
#   'period': 'FY',
#   'revenue': 38670840,
#   'costOfRevenue': 8313630.0,
#   'grossProfit': 30357210,
#   'grossProfitRatio': 0.7850155310823349,
#   'researchAndDevelopmentExpenses': 0.0,
#   'generalAndAdministrativeExpenses': 784994.0,
#   'sellingAndMarketingExpenses': 0.0,
#   'sellingGeneralAndAdministrativeExpenses': 805678.0,
#   'otherExpenses': 0.0,
#   'operatingExpenses': 805678.0,
#   'costAndExpenses': 8329020.0,
#   'interestExpense': 51897320,
#   'depreciationAndAmortization': 0.0,
#   'ebitda': 134136450,
#   'ebitdaratio': 3.468672,
#   'operatingIncome': 30341820,
#   'operatingIncomeRatio': 0.7846175567947321,
#   'totalOtherIncomeExpensesNet': -51897310,
#   'incomeBeforeTax': 82239130,
#   'incomeBeforeTaxRatio': 2.126644520781033,
#   'incomeTaxExpense': 0.0,
#   'netIncome': 82239130,
#   'netIncomeRatio': 2.126644520781033,
#   'eps': 3.96306,
#   'epsdiluted': 3.96306,
#   'weightedAverageShsOut': 20751420,
#   'weightedAverageShsOutDil': 20751420,
#   'link': '',
#   'finalLink': ''}]

# %%
def wacc(IS):
    EBIT = IS[0]['ebitda']-IS[0]['depreciationAndAmortization']
    inexp = IS[0]['interestExpense']
    incov_ratio = EBIT/inexp
    start = date(2020,8,12)
    tres = web.DataReader(['TB1YR'],'fred',start)
    risk = float(tres.iloc[-1])
    rf = risk/100
    print(rf, incov_ratio)

# %%
wacc(IS)
# Out:
# 0.0007000000000000001 0.0
